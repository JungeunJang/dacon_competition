# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# font 설정
import platform
path = "c:/Windows/Fonts/malgun.ttf"
from matplotlib import font_manager, rc

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else :
    print('Unknown system... sorry~')
import seaborn as sns

# 경고문 숨기기
import warnings
warnings.filterwarnings(action='ignore')

# %%
df = pd.read_csv('../다콘프로젝트/제주데이터/201901-202003.csv', encoding='utf-8', parse_dates=['REG_YYMM'])

# %%
df202003 = df[df['REG_YYMM'] == '202003']
df202003 = df202003[['REG_YYMM', 'CARD_SIDO_NM', 'STD_CLSS_NM', 'AMT']]
df202003.head()
# Out:
#          REG_YYMM CARD_SIDO_NM STD_CLSS_NM      AMT
# 23437284   202003           강원  건강보조식품 소매업  2529000
# 23437285   202003           강원  건강보조식품 소매업  1133650
# 23437286   202003           강원  건강보조식품 소매업   570800
# 23437287   202003           강원  건강보조식품 소매업  4192828
# 23437288   202003           강원  건강보조식품 소매업  3358900

# %%
df202003 = df202003.pivot_table(index=['REG_YYMM','CARD_SIDO_NM', 'STD_CLSS_NM'], values='AMT', aggfunc=np.sum)

# %%
df202003[df202003['CARD_SIDO_NM']=='제주']
# Out:
#     REG_YYMM CARD_SIDO_NM            STD_CLSS_NM          AMT
# 499   202003           제주             건강보조식품 소매업     80401810
# 500   202003           제주                골프장 운영업   1227910031
# 501   202003           제주            과실 및 채소 소매업    612861477
# 502   202003           제주      관광 민예품 및 선물용품 소매업     51733910
# 503   202003           제주   그외 기타 분류안된 오락관련 서비스업       313500
# 504   202003           제주           그외 기타 종합 소매업   3282513600
# 505   202003           제주           기타 대형 종합 소매업   4391495540
# 506   202003           제주           기타 수상오락 서비스업      1606700
# 507   202003           제주            기타 외국식 음식점업    412219149
# 508   202003           제주                 기타 주점업    891112022
# 509   202003           제주          기타음식료품위주종합소매업   3616119943
# 510   202003           제주              내항 여객 운송업     66432400
# 511   202003           제주                   마사지업      2660000
# 512   202003           제주                    면세점   2590699901
# ...

# %% [markdown]
# # 소비자 심리지수 적용을 해보자

# %%
sobi = pd.read_csv('../다콘프로젝트/제주데이터/9.2.4 소비자동향조사(한국은행_지.csv', encoding='cp949')

# %%
sobi = sobi.rename(columns={'Unnamed: 0':'BRANCH_CODE별'})

# %%
sobi2 = sobi.T

# %%
sobi2
# Out:
#                    0       1       2       3       4       5       6       7  \
# BRANCH_CODE별  Jan-19  Feb-19  Mar-19  Apr-19  May-19  Jun-19  Jul-19  Aug-19
# 부산                57      65      61      64      62      63      63      60
# 대구                58      62      64      66      62      63      59      56
# 경북                58      62      64      66      62      63      59      56
# 인천                62      66      69      71      69      69      66      64
# 광주                73      79      76      79      76      78      77      69
# 전남                73      79      76      79      76      78      77      69
# 대전                67      72      70      74      71      72      69      63
# 충남                67      72      70      74      71      72      69      63
# 울산                64      68      66      68      65      66      64      63
# 경기                68      72      71      74      70      70      69      65
# ...

# %%
sobi2.columns = sobi2.iloc[0]

# %%
sobi2 = sobi2.iloc[1:]

# %%
sobi2.to_csv('sobi.csv', encoding='utf-8-sig')

# %%
sobi3 = pd.read_csv('../다콘프로젝트/제주데이터/sobi.csv', encoding='cp949')

# %%
sobi3
# Out:
#    BRANCH_CODE별  201901  201902  201903  201904  201905  201906  201907  \
# 0            부산      57      65      61      64      62      63      63
# 1            대구      58      62      64      66      62      63      59
# 2            경북      58      62      64      66      62      63      59
# 3            인천      62      66      69      71      69      69      66
# 4            광주      73      79      76      79      76      78      77
# 5            전남      73      79      76      79      76      78      77
# 6            대전      67      72      70      74      71      72      69
# 7            충남      67      72      70      74      71      72      69
# 8            울산      64      68      66      68      65      66      64
# 9            경기      68      72      71      74      70      70      69
# 10           강원      64      69      70      71      67      68      68
# 11           충북      64      69      71      70      68      68      68
# ...

# %%
cols = ['202004']

# %%
data_price = sobi3.melt(id_vars=['BRANCH_CODE별'], value_vars=cols)

# %%
data_price = data_price.sort_values('BRANCH_CODE별', ascending=True)

# %%
data_price = data_price.set_index('BRANCH_CODE별')

# %%
data_price
# Out:
#              variable  value
# BRANCH_CODE별
# 강원             202004     34
# 경기             202004     33
# 경남             202004     28
# 경북             202004     26
# 광주             202004     40
# 대구             202004     26
# 대전             202004     32
# 부산             202004     29
# 서울             202004     30
# 세종             202004     32
# 울산             202004     31
# 인천             202004     31
# 전남             202004     40
# 전북             202004     40
# 제주             202004     32
# 충남             202004     32
# 충북             202004     34

# %%
df202003 = df202003.reset_index()

# %%
merge = df202003.merge(data_price, left_on='CARD_SIDO_NM', right_on='BRANCH_CODE별', how='left')

# %%
merge.head()
# Out:
#   REG_YYMM CARD_SIDO_NM        STD_CLSS_NM         AMT variable  value
# 0   202003           강원         건강보조식품 소매업    96059012   202004     34
# 1   202003           강원            골프장 운영업  2915797995   202004     34
# 2   202003           강원        과실 및 채소 소매업   994816943   202004     34
# 3   202003           강원  관광 민예품 및 선물용품 소매업    13317300   202004     34
# 4   202003           강원    그외 기타 스포츠시설 운영업     2075000   202004     34

# %%
merge.drop('variable', inplace=True, axis=1)

# %%
merge['moon'] = (merge['AMT'] * merge['value']) / 100

# %% [markdown]
# # submission용

# %%
merge2 = merge[['REG_YYMM', 'CARD_SIDO_NM', 'STD_CLSS_NM', 'moon']]

# %%
merge2 = merge2.rename(columns={'moon':'AMT'})

# %%
merge2
# Out:
#     REG_YYMM CARD_SIDO_NM            STD_CLSS_NM           AMT
# 0     202003           강원             건강보조식품 소매업  3.266006e+07
# 1     202003           강원                골프장 운영업  9.913713e+08
# 2     202003           강원            과실 및 채소 소매업  3.382378e+08
# 3     202003           강원      관광 민예품 및 선물용품 소매업  4.527882e+06
# 4     202003           강원        그외 기타 스포츠시설 운영업  7.055000e+05
# ..       ...          ...                    ...           ...
# 604   202003           충북  피자 햄버거 샌드위치 및 유사 음식점업  4.471834e+08
# 605   202003           충북                한식 음식점업  5.491844e+09
# 606   202003           충북                    호텔업  5.184507e+06
# 607   202003           충북          화장품 및 방향제 소매업  1.458197e+08
# 608   202003           충북               휴양콘도 운영업  4.329387e+06
#
# [609 rows x 4 columns]

# %%
submission = pd.read_csv('../다콘프로젝트/제주데이터/submission.csv', index_col=0)
submission = submission.loc[submission['REG_YYMM']==202004]
submission = submission[['REG_YYMM','CARD_SIDO_NM', 'STD_CLSS_NM']]

# %%
submission
# Out:
#      REG_YYMM CARD_SIDO_NM            STD_CLSS_NM
# id
# 0      202004           강원             건강보조식품 소매업
# 1      202004           강원                골프장 운영업
# 2      202004           강원            과실 및 채소 소매업
# 3      202004           강원      관광 민예품 및 선물용품 소매업
# 4      202004           강원   그외 기타 분류안된 오락관련 서비스업
# ..        ...          ...                    ...
# 692    202004           충북  피자 햄버거 샌드위치 및 유사 음식점업
# 693    202004           충북                한식 음식점업
# 694    202004           충북                    호텔업
# 695    202004           충북          화장품 및 방향제 소매업
# 696    202004           충북               휴양콘도 운영업
#
# [697 rows x 3 columns]

# %%
submission = submission.merge(merge2, left_on=['CARD_SIDO_NM', 'STD_CLSS_NM'], right_on=['CARD_SIDO_NM', 'STD_CLSS_NM'], how='left')
submission = submission.fillna(0)

# %%
submission.drop('REG_YYMM_y', inplace=True, axis=1)

# %%
submission = submission.rename(columns={'REG_YYMM_x':'REG_YYMM'})

# %%
submission.to_csv('submission.csv', encoding='utf-8-sig', sep=',')

# %%
AMT = list(submission['AMT'])

# %%
submission2 = pd.read_csv('../다콘프로젝트/제주데이터/submission.csv')

# %%
AMT = list(submission['AMT'])*2

# %%
submission2['AMT'] = AMT

# %%
submission2.to_csv('submission.csv', encoding='utf-8-sig', index=False)

# %%
submission
# Out:
#      REG_YYMM CARD_SIDO_NM            STD_CLSS_NM           AMT
# 0      202004           강원             건강보조식품 소매업  3.266006e+07
# 1      202004           강원                골프장 운영업  9.913713e+08
# 2      202004           강원            과실 및 채소 소매업  3.382378e+08
# 3      202004           강원      관광 민예품 및 선물용품 소매업  4.527882e+06
# 4      202004           강원   그외 기타 분류안된 오락관련 서비스업  0.000000e+00
# ..        ...          ...                    ...           ...
# 692    202004           충북  피자 햄버거 샌드위치 및 유사 음식점업  4.471834e+08
# 693    202004           충북                한식 음식점업  5.491844e+09
# 694    202004           충북                    호텔업  5.184507e+06
# 695    202004           충북          화장품 및 방향제 소매업  1.458197e+08
# 696    202004           충북               휴양콘도 운영업  4.329387e+06
#
# [697 rows x 4 columns]

# %%
submission2[submission2['REG_YYMM'] == 202007].AMT = 0

# %%
submission2
# Out:
#         id  REG_YYMM CARD_SIDO_NM            STD_CLSS_NM           AMT
# 0        0    202004           강원             건강보조식품 소매업  3.266006e+07
# 1        1    202004           강원                골프장 운영업  9.913713e+08
# 2        2    202004           강원            과실 및 채소 소매업  3.382378e+08
# 3        3    202004           강원      관광 민예품 및 선물용품 소매업  4.527882e+06
# 4        4    202004           강원   그외 기타 분류안된 오락관련 서비스업  0.000000e+00
# ...    ...       ...          ...                    ...           ...
# 1389  1389    202007           충북  피자 햄버거 샌드위치 및 유사 음식점업  4.471834e+08
# 1390  1390    202007           충북                한식 음식점업  5.491844e+09
# 1391  1391    202007           충북                    호텔업  5.184507e+06
# 1392  1392    202007           충북          화장품 및 방향제 소매업  1.458197e+08
# 1393  1393    202007           충북               휴양콘도 운영업  4.329387e+06
#
# [1394 rows x 5 columns]

# %%
t = pd.read_csv('../다콘프로젝트/제주데이터/T.csv', encoding='cp949')

# %%
t.to_csv('submission.csv', encoding='utf-8-sig', index=False)
